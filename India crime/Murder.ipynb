# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
data = pd.read_csv('32_Murder_victim_age_sex.csv')
data.head()
# Out:
#                    Area_Name  Year               Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1             Andhra Pradesh  2001  Murder - Female Victims
# 2          Arunachal Pradesh  2001  Murder - Female Victims
# 3                      Assam  2001  Murder - Female Victims
# 4                      Bihar  2001  Murder - Female Victims
#
#       Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0  2. Female Victims                   NaN              6
# 1  2. Female Victims                  67.0            607
# 2  2. Female Victims                   2.0             16
# 3  2. Female Victims                  11.0            128
# 4  2. Female Victims                  12.0            366
#
#    Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 0                     NaN                  NaN                     NaN
# 1                    15.0                 38.0                    43.0
# 2                     0.0                  0.0                     0.0
# 3                     8.0                  4.0                    23.0
# 4                     0.0                  0.0                    40.0
#
#    Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs
# 0                     4.0                     2.0
# 1                   269.0                   175.0
# 2                    10.0                     4.0
# 3                    45.0                    37.0
# 4                   191.0                   123.0

# %%
data['Group_Name'].unique()
# Out:
# array(['Murder - Female Victims', 'Murder - Male Victims',
#        'Murder - Total Victims'], dtype=object)

# %%
data.shape
# Out:
# (1018, 11)

# %%
data = data.fillna(0)

# %%
df = data[(data['Year'] == 2001)]
plt.figure(figsize=(10,6))
sns.barplot(df['Area_Name'], df['Victims_Total'], alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('States', fontsize=14)
plt.ylabel('Number of Murders', fontsize=14)
plt.title("Number of Murders with respect to each state", fontsize=16)
plt.show()

# %%
tn = df[(df['Area_Name'] == 'Uttar Pradesh')]
sns.barplot(ss.index, ss.values, alpha=0.8)
plt.show()

# %%
tn
# Out:
#          Area_Name  Year               Group_Name     Sub_Group_Name  \
# 30   Uttar Pradesh  2001  Murder - Female Victims  2. Female Victims
# 367  Uttar Pradesh  2001    Murder - Male Victims    1. Male Victims
# 707  Uttar Pradesh  2001   Murder - Total Victims           3. Total
#
#      Victims_Above_50_Yrs  Victims_Total  Victims_Upto_10_15_Yrs  \
# 30                  102.0           1323                    65.0
# 367                 722.0           6857                    93.0
# 707                 824.0           8180                   158.0
#
#      Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  \
# 30                  10.0                   103.0                   626.0
# 367                 29.0                   189.0                  3098.0
# 707                 39.0                   292.0                  3724.0
#
#      Victims_Upto_30_50_Yrs
# 30                    417.0
# 367                  2726.0
# 707                  3143.0

# %%
ss = tn['Group_Name'].value_counts()

# %%
a=[]
for i in range(2001,2011):
    yr = data[(data['Year'] == i)]
    a.append(sum(yr['Victims_Total']))
plt.figure(figsize=(10,6))
plt.plot(data['Year'].unique(),a, color = 'red')
plt.title('Number of Murders in India from 2001 to 2010')
plt.xlabel('Year')
plt.ylabel('Number of Murders')
plt.show()

# %%
top = [sum(df['Victims_Above_50_Yrs']),
       sum(df['Victims_Upto_10_15_Yrs']),
       sum(df['Victims_Upto_10_Yrs']),
       sum(df['Victims_Upto_15_18_Yrs']),
       sum(df['Victims_Upto_18_30_Yrs']),
       sum(df['Victims_Upto_30_50_Yrs']),
       ]
value = 'Victims_Above_50_Yrs','Victims_Upto_10_15_Yrs','Victims_Upto_10_Yrs','Victims_Upto_15_18_Yrs','Victims_Between_30-50_Yrs','Victims_Upto_18_30_Yrs'

# %%
top
# Out:
# [6922.0, 1174.0, 1680.0, 4218.0, 32824.0, 30454.0]

# %%
plt.figure(figsize=(10,6))
colors = ['gold', 'orange','yellowgreen', 'lightcoral', 'lightskyblue','green']
plt.pie(top, labels= value,colors=colors,autopct='%1.1f%%',startangle=140)
plt.show()
